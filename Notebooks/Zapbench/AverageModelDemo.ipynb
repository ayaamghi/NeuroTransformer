# %%
# !pip install git+https://github.com/google-research/zapbench.git#egg=zapbench
# Out:
# Collecting zapbench
#   Cloning https://github.com/google-research/zapbench.git to /private/var/folders/nx/pv3_j9vn6qxdw0yzd86gkqnw0000gn/T/pip-install-7iiz8xst/zapbench_3f85bf13a6d8496b9cee494671c0ae69
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/zapbench.git /private/var/folders/nx/pv3_j9vn6qxdw0yzd86gkqnw0000gn/T/pip-install-7iiz8xst/zapbench_3f85bf13a6d8496b9cee494671c0ae69
#   Resolved https://github.com/google-research/zapbench.git to commit c76cf007a0b544dc340c5e42b83b372b97114bc0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting absl-py (from zapbench)
#   Using cached absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting altair>5.0.0 (from zapbench)
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting chex (from zapbench)
#   Using cached chex-0.1.89-py3-none-any.whl.metadata (17 kB)
# Collecting clu (from zapbench)
#   Using cached clu-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Collecting connectomics (from zapbench)
#   Using cached connectomics-0.0.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting distrax (from zapbench)
#   Using cached distrax-0.1.5-py3-none-any.whl.metadata (13 kB)
# Collecting dm_pix (from zapbench)
#   Using cached dm_pix-0.4.4-py3-none-any.whl.metadata (7.1 kB)
# Collecting einops (from zapbench)
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting flax (from zapbench)
#   Using cached flax-0.10.6-py3-none-any.whl.metadata (11 kB)
# Collecting gin-config (from zapbench)
#   Using cached gin_config-0.5.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting grain-nightly==0.0.10 (from zapbench)
#   Using cached grain_nightly-0.0.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting immutabledict (from zapbench)
#   Using cached immutabledict-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting jax (from zapbench)
#   Using cached jax-0.6.0-py3-none-any.whl.metadata (22 kB)
# Collecting ml-collections (from zapbench)
#   Using cached ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Collecting numpy (from zapbench)
#   Using cached numpy-2.2.5-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting optax (from zapbench)
#   Using cached optax-0.2.4-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandas (from zapbench)
#   Using cached pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting scikit-learn (from zapbench)
#   Using cached scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting scikit-image (from zapbench)
#   Using cached scikit_image-0.25.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting tensorstore (from zapbench)
#   Using cached tensorstore-0.1.74-cp311-cp311-macosx_11_0_arm64.whl.metadata (21 kB)
# Collecting tensorflow-probability (from zapbench)
#   Using cached tensorflow_probability-0.25.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting tf-keras (from zapbench)
#   Using cached tf_keras-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting array-record (from grain-nightly==0.0.10->zapbench)
#   Using cached array_record-0.7.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (899 bytes)
# Collecting cloudpickle (from grain-nightly==0.0.10->zapbench)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting dm-tree (from grain-nightly==0.0.10->zapbench)
#   Using cached dm_tree-0.1.9-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting etils[epath,epy] (from grain-nightly==0.0.10->zapbench)
#   Using cached etils-1.12.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting jaxtyping (from grain-nightly==0.0.10->zapbench)
#   Using cached jaxtyping-0.3.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting more-itertools>=9.1.0 (from grain-nightly==0.0.10->zapbench)
#   Using cached more_itertools-10.7.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: jinja2 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from altair>5.0.0->zapbench) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from altair>5.0.0->zapbench) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair>5.0.0->zapbench)
#   Using cached narwhals-1.38.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: packaging in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from altair>5.0.0->zapbench) (25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from altair>5.0.0->zapbench) (4.13.2)
# Collecting jaxlib>=0.4.27 (from chex->zapbench)
#   Using cached jaxlib-0.6.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.2 kB)
# Collecting toolz>=0.9.0 (from chex->zapbench)
#   Using cached toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting ml_dtypes>=0.5.0 (from jax->zapbench)
#   Using cached ml_dtypes-0.5.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (21 kB)
# Collecting opt_einsum (from jax->zapbench)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting scipy>=1.11.1 (from jax->zapbench)
#   Using cached scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting wrapt (from clu->zapbench)
#   Using cached wrapt-1.17.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting dataclasses-json>=0.5.6 (from connectomics->zapbench)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting edt (from connectomics->zapbench)
#   Using cached edt-3.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (24 kB)
# Collecting sofima (from connectomics->zapbench)
#   Using cached sofima-0.1-py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from tensorflow-probability->zapbench) (1.17.0)
# Requirement already satisfied: decorator in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from tensorflow-probability->zapbench) (5.2.1)
# Collecting gast>=0.3.2 (from tensorflow-probability->zapbench)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting msgpack (from flax->zapbench)
#   Using cached msgpack-1.1.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting orbax-checkpoint (from flax->zapbench)
#   Using cached orbax_checkpoint-0.11.13-py3-none-any.whl.metadata (2.0 kB)
# Collecting rich>=11.1 (from flax->zapbench)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from flax->zapbench) (6.0.2)
# Collecting treescope>=0.1.7 (from flax->zapbench)
#   Using cached treescope-0.1.9-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from pandas->zapbench) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->zapbench)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->zapbench)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting networkx>=3.0 (from scikit-image->zapbench)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting pillow>=10.1 (from scikit-image->zapbench)
#   Using cached pillow-11.2.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.9 kB)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->zapbench)
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->zapbench)
#   Using cached tifffile-2025.3.30-py3-none-any.whl.metadata (32 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->zapbench)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->zapbench)
#   Using cached joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->zapbench)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting tensorflow<2.20,>=2.19 (from tf-keras->zapbench)
#   Using cached tensorflow-2.19.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.0 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json>=0.5.6->connectomics->zapbench)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json>=0.5.6->connectomics->zapbench)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair>5.0.0->zapbench) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair>5.0.0->zapbench) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair>5.0.0->zapbench) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair>5.0.0->zapbench) (0.24.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1->flax->zapbench)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from rich>=11.1->flax->zapbench) (2.19.1)
# Collecting astunparse>=1.6.0 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting google-pasta>=0.1.1 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached protobuf-5.29.4-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras->zapbench) (2.32.3)
# Requirement already satisfied: setuptools in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras->zapbench) (78.1.0)
# Collecting termcolor>=1.1.0 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached grpcio-1.71.0-cp311-cp311-macosx_10_14_universal2.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting numpy (from zapbench)
#   Using cached numpy-2.1.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting h5py>=3.11.0 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached h5py-3.13.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting fsspec (from etils[epath,epy]->grain-nightly==0.0.10->zapbench)
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting importlib_resources (from etils[epath,epy]->grain-nightly==0.0.10->zapbench)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting zipp (from etils[epath,epy]->grain-nightly==0.0.10->zapbench)
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting wadler-lindig>=0.1.3 (from jaxtyping->grain-nightly==0.0.10->zapbench)
#   Using cached wadler_lindig-0.1.5-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from jinja2->altair>5.0.0->zapbench) (3.0.2)
# Requirement already satisfied: nest_asyncio in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from orbax-checkpoint->flax->zapbench) (1.6.0)
# Collecting humanize (from orbax-checkpoint->flax->zapbench)
#   Using cached humanize-4.12.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting simplejson>=3.16.0 (from orbax-checkpoint->flax->zapbench)
#   Using cached simplejson-3.20.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting opencv-python>=4.5.5.62 (from sofima->connectomics->zapbench)
#   Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras->zapbench) (0.45.1)
# Collecting namex (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached namex-0.0.9-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached optree-0.15.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (48 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1->flax->zapbench)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras->zapbench) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras->zapbench) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras->zapbench) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras->zapbench) (2025.4.26)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras->zapbench)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.5.6->connectomics->zapbench)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached grain_nightly-0.0.10-cp311-cp311-macosx_11_0_arm64.whl (351 kB)
# Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Using cached absl_py-2.2.2-py3-none-any.whl (135 kB)
# Using cached chex-0.1.89-py3-none-any.whl (99 kB)
# Using cached jax-0.6.0-py3-none-any.whl (2.3 MB)
# Using cached clu-0.0.12-py3-none-any.whl (101 kB)
# Using cached connectomics-0.0.3-py3-none-any.whl (255 kB)
# Using cached distrax-0.1.5-py3-none-any.whl (319 kB)
# Using cached tensorflow_probability-0.25.0-py2.py3-none-any.whl (7.0 MB)
# Using cached dm_pix-0.4.4-py3-none-any.whl (56 kB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached flax-0.10.6-py3-none-any.whl (447 kB)
# Using cached gin_config-0.5.0-py3-none-any.whl (61 kB)
# Using cached immutabledict-4.2.1-py3-none-any.whl (4.7 kB)
# Using cached ml_collections-1.1.0-py3-none-any.whl (76 kB)
# Using cached optax-0.2.4-py3-none-any.whl (319 kB)
# Using cached pandas-2.2.3-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
# Using cached scikit_image-0.25.2-cp311-cp311-macosx_12_0_arm64.whl (13.2 MB)
# Using cached scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl (11.1 MB)
# Using cached tensorstore-0.1.74-cp311-cp311-macosx_11_0_arm64.whl (13.3 MB)
# Using cached tf_keras-2.19.0-py3-none-any.whl (1.7 MB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached jaxlib-0.6.0-cp311-cp311-macosx_11_0_arm64.whl (53.5 MB)
# Using cached joblib-1.5.0-py3-none-any.whl (307 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached ml_dtypes-0.5.1-cp311-cp311-macosx_10_9_universal2.whl (671 kB)
# Using cached more_itertools-10.7.0-py3-none-any.whl (65 kB)
# Using cached narwhals-1.38.0-py3-none-any.whl (338 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached pillow-11.2.1-cp311-cp311-macosx_11_0_arm64.whl (3.0 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached scipy-1.15.2-cp311-cp311-macosx_14_0_arm64.whl (22.4 MB)
# Using cached tensorflow-2.19.0-cp311-cp311-macosx_12_0_arm64.whl (252.6 MB)
# Using cached numpy-2.1.3-cp311-cp311-macosx_14_0_arm64.whl (5.4 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tifffile-2025.3.30-py3-none-any.whl (226 kB)
# Using cached toolz-1.0.0-py3-none-any.whl (56 kB)
# Using cached treescope-0.1.9-py3-none-any.whl (182 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached wrapt-1.17.2-cp311-cp311-macosx_11_0_arm64.whl (38 kB)
# Using cached array_record-0.7.2-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
# Using cached dm_tree-0.1.9-cp311-cp311-macosx_10_9_universal2.whl (173 kB)
# Using cached edt-3.0.0-cp311-cp311-macosx_11_0_arm64.whl (284 kB)
# Using cached jaxtyping-0.3.2-py3-none-any.whl (55 kB)
# Using cached msgpack-1.1.0-cp311-cp311-macosx_11_0_arm64.whl (81 kB)
# Using cached orbax_checkpoint-0.11.13-py3-none-any.whl (442 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.71.0-cp311-cp311-macosx_10_14_universal2.whl (11.3 MB)
# Using cached h5py-3.13.0-cp311-cp311-macosx_11_0_arm64.whl (2.9 MB)
# Using cached keras-3.9.2-py3-none-any.whl (1.3 MB)
# Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
# Using cached protobuf-5.29.4-cp38-abi3-macosx_10_9_universal2.whl (417 kB)
# Using cached simplejson-3.20.1-cp311-cp311-macosx_11_0_arm64.whl (74 kB)
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Using cached tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_12_0_arm64.whl (3.5 MB)
# Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached wadler_lindig-0.1.5-py3-none-any.whl (20 kB)
# Using cached etils-1.12.2-py3-none-any.whl (167 kB)
# Using cached fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached humanize-4.12.3-py3-none-any.whl (128 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached markdown-3.8-py3-none-any.whl (106 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached namex-0.0.9-py3-none-any.whl (5.8 kB)
# Using cached optree-0.15.0-cp311-cp311-macosx_11_0_arm64.whl (338 kB)
# Building wheels for collected packages: zapbench
#   Building wheel for zapbench (pyproject.toml) ... done
#   Created wheel for zapbench: filename=zapbench-0.1.0-py3-none-any.whl size=123029 sha256=4750fbef586c75b574c50a0dee2cb6e9af7aaddb78c3f72c7bd7bb16eb950cb0
#   Stored in directory: /private/var/folders/nx/pv3_j9vn6qxdw0yzd86gkqnw0000gn/T/pip-ephem-wheel-cache-g6b3rc8c/wheels/cb/67/7d/5f07f5f214a9eef81d17da3be3db848545a0bfaf5cbfa5beb3
# Successfully built zapbench
# Installing collected packages: pytz, namex, libclang, gin-config, flatbuffers, zipp, wrapt, werkzeug, wadler-lindig, tzdata, toolz, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, simplejson, protobuf, pillow, optree, opt_einsum, numpy, networkx, narwhals, mypy-extensions, msgpack, more-itertools, mdurl, marshmallow, markdown, lazy-loader, joblib, importlib_resources, immutabledict, humanize, grpcio, google-pasta, gast, fsspec, etils, einops, cloudpickle, astunparse, absl-py, typing-inspect, treescope, tifffile, tensorboard, scipy, pandas, opencv-python, ml_dtypes, ml-collections, markdown-it-py, jaxtyping, imageio, h5py, edt, dm-tree, tensorstore, tensorflow-probability, scikit-learn, scikit-image, rich, jaxlib, dataclasses-json, keras, jax, array-record, altair, tensorflow, orbax-checkpoint, grain-nightly, chex, tf-keras, optax, dm_pix, distrax, flax, clu, sofima, connectomics, zapbench
# Successfully installed absl-py-2.2.2 altair-5.5.0 array-record-0.7.2 astunparse-1.6.3 chex-0.1.89 cloudpickle-3.1.1 clu-0.0.12 connectomics-0.0.3 dataclasses-json-0.6.7 distrax-0.1.5 dm-tree-0.1.9 dm_pix-0.4.4 edt-3.0.0 einops-0.8.1 etils-1.12.2 flatbuffers-25.2.10 flax-0.10.6 fsspec-2025.3.2 gast-0.6.0 gin-config-0.5.0 google-pasta-0.2.0 grain-nightly-0.0.10 grpcio-1.71.0 h5py-3.13.0 humanize-4.12.3 imageio-2.37.0 immutabledict-4.2.1 importlib_resources-6.5.2 jax-0.6.0 jaxlib-0.6.0 jaxtyping-0.3.2 joblib-1.5.0 keras-3.9.2 lazy-loader-0.4 libclang-18.1.1 markdown-3.8 markdown-it-py-3.0.0 marshmallow-3.26.1 mdurl-0.1.2 ml-collections-1.1.0 ml_dtypes-0.5.1 more-itertools-10.7.0 msgpack-1.1.0 mypy-extensions-1.1.0 namex-0.0.9 narwhals-1.38.0 networkx-3.4.2 numpy-2.1.3 opencv-python-4.11.0.86 opt_einsum-3.4.0 optax-0.2.4 optree-0.15.0 orbax-checkpoint-0.11.13 pandas-2.2.3 pillow-11.2.1 protobuf-5.29.4 pytz-2025.2 rich-14.0.0 scikit-image-0.25.2 scikit-learn-1.6.1 scipy-1.15.2 simplejson-3.20.1 sofima-0.1 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 tensorflow-probability-0.25.0 tensorstore-0.1.74 termcolor-3.1.0 tf-keras-2.19.0 threadpoolctl-3.6.0 tifffile-2025.3.30 toolz-1.0.0 treescope-0.1.9 typing-inspect-0.9.0 tzdata-2025.2 wadler-lindig-0.1.5 werkzeug-3.1.3 wrapt-1.17.2 zapbench-0.1.0 zipp-3.21.0
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from zapbench import constants
from zapbench import data_utils
from zapbench.ts_forecasting import data_source

# %%
# Out:
# <module 'zapbench.constants' from '/Users/ayaam/Programming/School/NeuroTransformer/.venv/lib/python3.11/site-packages/zapbench/constants.py'>
